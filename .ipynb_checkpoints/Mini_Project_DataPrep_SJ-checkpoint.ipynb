# %%
from __future__ import print_function

import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt 
# %matplotlib inline

df1 = pd.read_csv('ABNB_NY_V2.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0    id                                              name  \
# 0           0  2539                Clean & quiet apt home by the park
# 1           1  2595                             Skylit Midtown Castle
# 2           2  3647               THE VILLAGE OF HARLEM....NEW YORK !
# 3           3  3831                   Cozy Entire Floor of Brownstone
# 4           4  5022  Entire Apt: Spacious Studio/Loft by central park
#
#    host_id    host_name neighbourhood_group neighbourhood  latitude  \
# 0     2787         John            Brooklyn    Kensington  40.64749
# 1     2845     Jennifer           Manhattan       Midtown  40.75362
# 2     4632    Elisabeth           Manhattan        Harlem  40.80902
# 3     4869  LisaRoxanne            Brooklyn  Clinton Hill  40.68514
# 4     7192        Laura           Manhattan   East Harlem  40.79851
#
#    longitude        room_type  ...      ZIP  dist_subway  cnt_all  \
# ...

# %%
df1[['neighbourhood_group','neighbourhood','room_type',]].describe().transpose()
# Out:
#                      count unique              top   freq
# neighbourhood_group  48895      5        Manhattan  21661
# neighbourhood        48895    221     Williamsburg   3920
# room_type            48895      3  Entire home/apt  25409

# %%
#https://datatofish.com/if-condition-in-pandas-dataframe/
df1.loc[(df['room_type'] == 'Private room') | (df['room_type'] =='Shared room'), 'room_type'] = 'shared home'
df1.loc[(df['room_type'] == 'Entire home/apt'), 'room_type'] = 'entire home'

# %%
df1[['neighbourhood_group','neighbourhood','room_type',]].describe().transpose()
# Out:
#                      count unique           top   freq
# neighbourhood_group  48895      5     Manhattan  21661
# neighbourhood        48895    221  Williamsburg   3920
# room_type            48895      2   entire home  25409

# %%
df2 = pd.read_csv('abnb_grid2_copy.csv')
df2.head()
# Out:
#      ID  cnt_shared  price_shared
# 0  2539           4     87.500000
# 1  2595           4    250.750000
# 2  3647          36    102.138889
# 3  3831          11     70.909091
# 4  5022           7     81.285714

# %%
len(df1), len(df2),
# Out:
# (48895, 48895)

# %%
df2 = df2.rename(columns = {"ID":"id"})
df2.head()
# Out:
#      id  cnt_shared  price_shared
# 0  2539           4     87.500000
# 1  2595           4    250.750000
# 2  3647          36    102.138889
# 3  3831          11     70.909091
# 4  5022           7     81.285714

# %%
ab_nyc2 = pd.merge(df1, df2, on = 'id')
ab_nyc2.head()
# Out:
#    Unnamed: 0    id                                              name  \
# 0           0  2539                Clean & quiet apt home by the park
# 1           1  2595                             Skylit Midtown Castle
# 2           2  3647               THE VILLAGE OF HARLEM....NEW YORK !
# 3           3  3831                   Cozy Entire Floor of Brownstone
# 4           4  5022  Entire Apt: Spacious Studio/Loft by central park
#
#    host_id    host_name neighbourhood_group neighbourhood  latitude  \
# 0     2787         John            Brooklyn    Kensington  40.64749
# 1     2845     Jennifer           Manhattan       Midtown  40.75362
# 2     4632    Elisabeth           Manhattan        Harlem  40.80902
# 3     4869  LisaRoxanne            Brooklyn  Clinton Hill  40.68514
# 4     7192        Laura           Manhattan   East Harlem  40.79851
#
#    longitude    room_type  ...  cnt_all  cnt_entire_home  cnt_private_room  \
# ...

# %%
ab_nyc2[['neighbourhood_group','neighbourhood','room_type',]].describe().transpose()
# Out:
#                      count unique           top   freq
# neighbourhood_group  48895      5     Manhattan  21661
# neighbourhood        48895    221  Williamsburg   3920
# room_type            48895      2   entire home  25409

# %%
columns = ['cnt_private_room','cnt_shared_room', 'avgprice_private_room','avgprice_shared_room']

# %%
columns
# Out:
# ['cnt_private_room',
#  'cnt_shared_room',
#  'avgprice_private_room',
#  'avgprice_shared_room']

# %%
ab_nyc2.drop(columns, inplace=True, axis=1)

# %%
ab_nyc2.head()
# Out:
#    Unnamed: 0    id                                              name  \
# 0           0  2539                Clean & quiet apt home by the park
# 1           1  2595                             Skylit Midtown Castle
# 2           2  3647               THE VILLAGE OF HARLEM....NEW YORK !
# 3           3  3831                   Cozy Entire Floor of Brownstone
# 4           4  5022  Entire Apt: Spacious Studio/Loft by central park
#
#    host_id    host_name neighbourhood_group neighbourhood  latitude  \
# 0     2787         John            Brooklyn    Kensington  40.64749
# 1     2845     Jennifer           Manhattan       Midtown  40.75362
# 2     4632    Elisabeth           Manhattan        Harlem  40.80902
# 3     4869  LisaRoxanne            Brooklyn  Clinton Hill  40.68514
# 4     7192        Laura           Manhattan   East Harlem  40.79851
#
#    longitude    room_type  ...  calculated_host_listings_count  \
# 0  -73.97237  shared home  ...                               6
# ...

# %%
ab_nyc2 = ab_nyc2.rename(columns = {"price_shared":"avgprice_shared"})

# %%
ab_nyc2.head()
# Out:
#    Unnamed: 0    id                                              name  \
# 0           0  2539                Clean & quiet apt home by the park
# 1           1  2595                             Skylit Midtown Castle
# 2           2  3647               THE VILLAGE OF HARLEM....NEW YORK !
# 3           3  3831                   Cozy Entire Floor of Brownstone
# 4           4  5022  Entire Apt: Spacious Studio/Loft by central park
#
#    host_id    host_name neighbourhood_group neighbourhood  latitude  \
# 0     2787         John            Brooklyn    Kensington  40.64749
# 1     2845     Jennifer           Manhattan       Midtown  40.75362
# 2     4632    Elisabeth           Manhattan        Harlem  40.80902
# 3     4869  LisaRoxanne            Brooklyn  Clinton Hill  40.68514
# 4     7192        Laura           Manhattan   East Harlem  40.79851
#
#    longitude    room_type  ...  calculated_host_listings_count  \
# 0  -73.97237  shared home  ...                               6
# ...

# %%
ab_nyc2.to_csv("ABNB_NY_V3.csv")
